# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# %%
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

# %%
filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

words = read_data(filename)
print('Data size', len(words))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

# %%
def build_dataset(words, vocabulary_size):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words, vocabulary_size)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
data_index = 0

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3084 originated -> 12 as
# 3084 originated -> 5239 anarchism
# 12 as -> 6 a
# 12 as -> 3084 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

# %%
graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print("Initialized")

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  317.126342773
# Nearest to called: tribulations, encampments, telepathic, hanse, consequentialism, secrets, us, bhutto,
# Nearest to state: creates, physicist, connick, militaristic, dense, premiership, laurel, garz,
# Nearest to more: ocs, unicef, horseman, bentheim, bears, kanagawa, cher, indiscriminately,
# Nearest to system: interests, pursuant, uppermost, bysshe, sunflower, militarily, clodius, mulholland,
# Nearest to to: revamped, correlates, crosby, merchandising, matthias, franchising, eucalyptus, hospitalized,
# Nearest to on: teardrop, resigns, flutter, gundobad, stocks, mahabharata, survivals, indymedia,
# Nearest to two: bouchard, ipc, doves, manco, consistory, rsted, caleb, aviator,
# Nearest to there: hhs, unix, streamlined, pk, ssbauer, franck, loudspeaker, vignette,
# Nearest to from: rask, finnic, demurrage, timor, rulemaking, apollodorus, moderne, definite,
# Nearest to new: astronomy, mozambican, abatis, parlour, ethereal, myanmar, gestures, hispano,
# Nearest to may: winsor, hilliard, eldridge, inclusive, bute, carrie, esther, reflectivity,
# Nearest to d: reactivated, chaney, worsening, bargaining, hold, mcmanus, depended, druidism,
# Nearest to b: mayoral, narrow, restorations, hermit, orthography, hellboy, continuum, yitzchak,
# Nearest to an: plumb, refounded, naacp, pci, adolescent, spectator, iv, rollin,
# Nearest to not: exercising, vow, magog, reals, unschooling, resistant, inordinate, confirmed,
# Nearest to other: bipm, inclined, replicas, debates, tuff, inc, seth, serbs,
# Average loss at step  2000 :  113.202786053
# Average loss at step  4000 :  52.9756335866
# Average loss at step  6000 :  33.4077995597
# Average loss at step  8000 :  23.3955015473
# Average loss at step  10000 :  17.7195118679
# Nearest to called: us, fao, sleep, here, melbourne, voted, head, atomic,
# Nearest to state: creates, physicist, dense, say, acquired, lighthouse, alexis, fourteen,
# Nearest to more: unicef, usage, permitted, bears, actor, over, returning, protocols,
# Nearest to system: interests, steve, popular, scrimmage, sunflower, improving, ancestry, point,
# Nearest to to: and, in, sacred, with, irrigation, yeast, of, for,
# Nearest to on: in, and, of, frau, one, archie, altenberg, to,
# Nearest to two: one, nine, five, austin, six, four, agave, archie,
# Nearest to there: unix, altenberg, streamlined, force, inert, they, lymphoma, mongols,
# Nearest to from: in, and, of, for, mctaggart, refrigerator, higher, timor,
# Nearest to new: and, astronomy, myanmar, colonel, therapists, propanol, prakrit, coherent,
# Nearest to may: can, exception, soluble, altenberg, sequencer, avicenna, archie, abolitionist,
# Nearest to d: hold, disease, zero, cc, depended, hiroshima, horst, connects,
# Nearest to b: narrow, routledge, archie, ampere, assumed, explore, trauma, victoria,
# Nearest to an: the, attitude, buddhism, mathbf, economists, dialect, thailand, iv,
# Nearest to not: who, taught, exercising, huxley, confirmed, archie, cuts, surprise,
# Nearest to other: altenberg, inc, combined, inclined, marple, frau, economic, bishop,
# Average loss at step  12000 :  13.9154929842
# Average loss at step  14000 :  11.8382347558
# Average loss at step  16000 :  10.1057580069
# Average loss at step  18000 :  8.51378631431
# Average loss at step  20000 :  7.8974443047
# Nearest to called: us, dasyprocta, inadvertently, voted, epistles, melbourne, here, isaac,
# Nearest to state: creates, physicist, acquired, dense, shell, periods, alexis, fourteen,
# Nearest to more: unicef, perceptual, permitted, operatorname, usage, bears, over, returning,
# Nearest to system: interests, steve, scrimmage, popular, mormonism, theo, sunflower, improving,
# Nearest to to: and, for, apologia, in, irrigation, with, into, dasyprocta,
# Nearest to on: in, and, of, for, from, at, baum, to,
# Nearest to two: one, three, five, four, six, zero, nine, operatorname,
# Nearest to there: it, they, pk, unix, circ, streamlined, not, ear,
# Nearest to from: in, and, for, by, of, with, on, dasyprocta,
# Nearest to new: astronomy, friars, parlour, spa, finn, and, myanmar, weldon,
# Nearest to may: can, exception, soluble, abolitionist, carrie, numerals, avicenna, sequencer,
# Nearest to d: b, hold, cc, dasyprocta, disease, worsening, hiroshima, amos,
# Nearest to b: d, and, operatorname, dasyprocta, yin, routledge, narrow, gloucester,
# Nearest to an: the, operatorname, iv, attitude, buddhism, dasyprocta, homomorphism, thailand,
# Nearest to not: vow, who, it, dasyprocta, they, no, to, confirmed,
# Nearest to other: altenberg, inc, combined, inclined, marple, three, serbs, homomorphism,
# Average loss at step  22000 :  7.01909125137
# Average loss at step  24000 :  6.84473108876
# Average loss at step  26000 :  6.74570211065
# Average loss at step  28000 :  6.39489484942
# Average loss at step  30000 :  5.89399567211
# Nearest to called: us, inadvertently, voted, personification, dasyprocta, isaac, here, secrets,
# Nearest to state: creates, physicist, dearborn, acquired, periods, shell, fourteen, alexis,
# Nearest to more: airshow, unicef, operatorname, permitted, perceptual, usage, markers, bears,
# Nearest to system: interests, mormonism, steve, popular, scrimmage, alain, almighty, sunflower,
# Nearest to to: for, apologia, would, with, into, and, nine, dasyprocta,
# Nearest to on: in, for, at, two, into, from, by, and,
# Nearest to two: four, three, five, one, six, eight, seven, operatorname,
# Nearest to there: it, they, he, which, pk, not, circ, mongols,
# Nearest to from: in, with, by, of, and, into, for, dasyprocta,
# Nearest to new: friars, spa, ethereal, astronomy, weldon, finn, prakrit, aaron,
# Nearest to may: can, would, will, soluble, cannot, abolitionist, could, numerals,
# Nearest to d: b, hold, airshow, cc, ansgar, disease, dasyprocta, worsening,
# Nearest to b: d, and, one, routledge, yin, dasyprocta, operatorname, variance,
# Nearest to an: pci, the, operatorname, attitude, just, buddhism, thailand, iv,
# Nearest to not: vow, who, they, it, to, dasyprocta, no, she,
# Nearest to other: altenberg, combined, inclined, many, inc, marple, afloat, antibiotics,
# Average loss at step  32000 :  6.00674721122
# Average loss at step  34000 :  5.68936476684
# Average loss at step  36000 :  5.77807441497
# Average loss at step  38000 :  5.49401140749
# Average loss at step  40000 :  5.27194014347
# Nearest to called: inadvertently, personification, UNK, voted, gibb, us, atomic, dasyprocta,
# Nearest to state: creates, physicist, dearborn, shell, acquired, periods, laurel, fourteen,
# Nearest to more: airshow, unicef, less, operatorname, permitted, usage, markers, perceptual,
# Nearest to system: interests, steve, mormonism, popular, alain, scrimmage, heralded, ancestry,
# Nearest to to: zero, would, for, with, apologia, can, nine, operatorname,
# Nearest to on: in, at, and, from, for, recitative, through, two,
# Nearest to two: three, four, one, six, five, seven, eight, zero,
# Nearest to there: they, it, which, he, pk, not, mongols, ear,
# Nearest to from: in, into, recitative, dasyprocta, by, with, on, through,
# Nearest to new: friars, spa, ethereal, recitative, aaron, finn, parlour, aral,
# Nearest to may: can, would, will, vdc, cannot, could, soluble, seven,
# Nearest to d: b, hold, cc, airshow, ansgar, zero, chaney, sperry,
# Nearest to b: d, operatorname, dasyprocta, and, one, circ, UNK, yin,
# Nearest to an: pci, the, attitude, operatorname, just, iv, thailand, akimbo,
# Nearest to not: vow, they, who, it, dasyprocta, she, akh, to,
# Nearest to other: many, vdc, marple, weren, three, altenberg, combined, inclined,
# Average loss at step  42000 :  5.35955972755
# Average loss at step  44000 :  5.25750531518
# Average loss at step  46000 :  5.23159630775
# Average loss at step  48000 :  5.23831461644
# Average loss at step  50000 :  4.9800523659
# Nearest to called: gibb, personification, and, dasyprocta, voted, inadvertently, atomic, UNK,
# Nearest to state: creates, physicist, marek, laurel, dearborn, shell, periods, burdens,
# Nearest to more: airshow, less, operatorname, unicef, permitted, usage, markers, most,
# Nearest to system: interests, mormonism, popular, alain, steve, heralded, scrimmage, niche,
# Nearest to to: would, dasyprocta, apologia, kapoor, and, nine, can, for,
# Nearest to on: in, at, two, recitative, blaise, from, through, ulyanov,
# Nearest to two: three, four, one, six, five, operatorname, seven, eight,
# Nearest to there: they, it, he, which, pk, not, mongols, franck,
# Nearest to from: in, into, through, recitative, for, and, by, eight,
# Nearest to new: friars, spa, ethereal, recitative, parlour, aaron, aral, weldon,
# Nearest to may: can, would, will, could, vdc, cannot, mangeshkar, soluble,
# Nearest to d: b, cc, hold, airshow, ansgar, n, dasyprocta, worsening,
# Nearest to b: d, operatorname, dasyprocta, circ, six, ampere, yin, italians,
# Nearest to an: pci, thailand, the, just, operatorname, iv, scots, attitude,
# Nearest to not: vow, they, who, it, dasyprocta, to, she, akh,
# Nearest to other: many, weren, vdc, marple, combined, inclined, three, ignorance,
# Average loss at step  52000 :  5.04580963504
# Average loss at step  54000 :  5.16704267669
# Average loss at step  56000 :  5.05072033072
# Average loss at step  58000 :  5.05470679343
# Average loss at step  60000 :  4.94785500526
# Nearest to called: gibb, voted, personification, atomic, used, inadvertently, dasyprocta, fletcher,
# Nearest to state: creates, marek, physicist, dearborn, laurel, periods, acquired, shell,
# Nearest to more: less, airshow, operatorname, most, responsible, markers, permitted, unicef,
# Nearest to system: interests, mormonism, alain, popular, heralded, steve, niche, ancestry,
# Nearest to to: would, for, can, not, ursus, operatorname, kapoor, quipped,
# Nearest to on: in, at, pulau, through, blaise, from, recitative, ulyanov,
# Nearest to two: three, four, one, six, five, operatorname, ursus, eight,
# Nearest to there: they, it, he, corum, which, pk, mongols, not,
# Nearest to from: in, into, recitative, through, after, eight, within, refrigerator,
# Nearest to new: friars, spa, ethereal, recitative, aaron, aral, prakrit, fallacies,
# Nearest to may: can, would, will, could, cannot, vdc, must, mangeshkar,
# Nearest to d: b, hold, cc, n, chaney, ansgar, airshow, pulau,
# Nearest to b: d, ampere, italians, selecting, dasyprocta, operatorname, restorations, janeiro,
# Nearest to an: pci, attitude, just, thailand, plumb, operatorname, scots, the,
# Nearest to not: they, vow, it, who, to, dasyprocta, generally, she,
# Nearest to other: many, two, weren, marple, combined, three, these, vdc,
# Average loss at step  62000 :  5.01888324463
# Average loss at step  64000 :  4.83346462148
# Average loss at step  66000 :  4.60265011048
# Average loss at step  68000 :  4.97232766712
# Average loss at step  70000 :  4.90085333359
# Nearest to called: used, voted, gibb, personification, atomic, thaler, inadvertently, dasyprocta,
# Nearest to state: creates, cebus, marek, cvd, dinar, dearborn, laurel, physicist,
# Nearest to more: less, airshow, most, operatorname, responsible, markers, usage, permitted,
# Nearest to system: interests, alain, heralded, mormonism, mico, rogue, dist, cebus,
# Nearest to to: would, ursus, not, quipped, kapoor, can, nine, apologia,
# Nearest to on: in, at, through, pulau, mitral, blaise, ulyanov, mico,
# Nearest to two: three, four, six, five, one, eight, seven, mico,
# Nearest to there: they, it, he, corum, mongols, pk, still, not,
# Nearest to from: into, in, recitative, through, after, and, refrigerator, dasyprocta,
# Nearest to new: friars, spa, ethereal, cebus, recitative, fallacies, coherent, parlour,
# Nearest to may: can, would, will, could, cannot, must, mangeshkar, vdc,
# Nearest to d: b, n, cc, UNK, hold, ansgar, chaney, worsening,
# Nearest to b: d, UNK, dasyprocta, operatorname, circ, ampere, upanija, cebus,
# Nearest to an: pci, attitude, thailand, just, dept, iv, operatorname, plumb,
# Nearest to not: they, vow, it, dasyprocta, generally, akh, also, to,
# Nearest to other: many, cardiomyopathy, weren, some, these, marple, ignorance, vdc,
# Average loss at step  72000 :  4.74338534606
# Average loss at step  74000 :  4.80504216146
# Average loss at step  76000 :  4.7304462167
# Average loss at step  78000 :  4.79825764072
# Average loss at step  80000 :  4.81830701041
# Nearest to called: used, gibb, thaler, dasyprocta, voted, personification, fletcher, callithrix,
# Nearest to state: creates, cebus, cvd, busan, marek, dinar, physicist, periods,
# Nearest to more: less, most, airshow, operatorname, markers, responsible, usage, too,
# Nearest to system: interests, alain, heralded, environment, rogue, mormonism, point, tupolev,
# Nearest to to: would, ursus, pontificia, apologia, dasyprocta, circ, operatorname, kapoor,
# Nearest to on: in, through, at, mitral, pulau, ulyanov, blaise, recitative,
# Nearest to two: three, four, six, five, one, seven, iit, eight,
# Nearest to there: they, it, he, still, which, pk, corum, now,
# Nearest to from: into, in, through, recitative, after, during, by, pontificia,
# Nearest to new: friars, cebus, spa, recitative, ethereal, symbolist, davidson, coherent,
# Nearest to may: can, would, will, could, must, cannot, mangeshkar, vdc,
# Nearest to d: b, n, cc, UNK, hold, chaney, ansgar, connects,
# Nearest to b: d, UNK, dasyprocta, operatorname, three, circ, ampere, upanija,
# Nearest to an: pci, attitude, thailand, the, sess, goss, just, operatorname,
# Nearest to not: vow, they, dasyprocta, it, guaranteeing, be, generally, akh,
# Nearest to other: many, cardiomyopathy, some, weren, ignorance, various, marple, different,
# Average loss at step  82000 :  4.77551356244
# Average loss at step  84000 :  4.74685732722
# Average loss at step  86000 :  4.77839504135
# Average loss at step  88000 :  4.74776409495
# Average loss at step  90000 :  4.72895810688
# Nearest to called: used, voted, gibb, dasyprocta, thaler, callithrix, personification, microcebus,
# Nearest to state: creates, cebus, cvd, busan, marek, dinar, question, periods,
# Nearest to more: less, most, airshow, operatorname, responsible, too, markers, usage,
# Nearest to system: interests, heralded, alain, environment, mico, rogue, tupolev, cebus,
# Nearest to to: would, can, ursus, will, pontificia, nine, circ, quipped,
# Nearest to on: in, through, at, mitral, pulau, ulyanov, blaise, recitative,
# Nearest to two: three, four, five, one, six, seven, eight, mico,
# Nearest to there: they, it, he, still, pk, now, often, which,
# Nearest to from: into, in, recitative, through, after, during, pontificia, by,
# Nearest to new: cebus, friars, spa, recitative, davidson, coherent, dasyprocta, cardiomyopathy,
# Nearest to may: can, would, will, could, must, cannot, might, mangeshkar,
# Nearest to d: b, UNK, n, six, cc, ansgar, hold, chaney,
# Nearest to b: d, UNK, six, ampere, operatorname, four, dasyprocta, circ,
# Nearest to an: pci, goss, attitude, thailand, sess, iv, participated, plumb,
# Nearest to not: they, vow, dasyprocta, be, generally, it, now, akh,
# Nearest to other: many, cardiomyopathy, some, various, two, different, weren, three,
# Average loss at step  92000 :  4.67742826807
# Average loss at step  94000 :  4.72587963414
# Average loss at step  96000 :  4.70626673746
# Average loss at step  98000 :  4.57710649604
# Average loss at step  100000 :  4.69751618683
# Nearest to called: used, voted, gibb, fletcher, thaler, callithrix, personification, reformers,
# Nearest to state: creates, cebus, cvd, busan, marek, dinar, question, thaler,
# Nearest to more: less, most, airshow, operatorname, alfv, responsible, markers, usage,
# Nearest to system: interests, alain, heralded, environment, tupolev, rogue, mico, point,
# Nearest to to: would, ursus, pontificia, circ, operatorname, kapoor, dasyprocta, can,
# Nearest to on: in, through, at, mitral, blaise, pulau, ulyanov, within,
# Nearest to two: four, three, five, seven, six, one, eight, mico,
# Nearest to there: they, it, he, still, which, now, often, pk,
# Nearest to from: into, in, through, recitative, during, pontificia, after, under,
# Nearest to new: spa, friars, cebus, coherent, recitative, fallacies, davidson, lifes,
# Nearest to may: can, would, will, could, must, cannot, might, should,
# Nearest to d: b, six, airshow, cc, n, dasyprocta, pulau, pontificia,
# Nearest to b: d, dasyprocta, operatorname, ampere, circ, italians, upanija, cebus,
# Nearest to an: pci, thailand, goss, attitude, iv, sess, participated, plumb,
# Nearest to not: they, vow, generally, dasyprocta, be, it, also, now,
# Nearest to other: many, various, cardiomyopathy, weren, different, tuff, some, three,

# %%
# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)
#   plt.imshow(plt)

# %%
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE



tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels)
