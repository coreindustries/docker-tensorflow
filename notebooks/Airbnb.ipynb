# %%
# https://www.dataquest.io/blog/machine-learning-tutorial/
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

import pandas as pd
import numpy as np

# %matplotlib inline

# !curl -o listings.csv.gz http://data.insideairbnb.com/united-states/dc/washington-dc/2015-10-03/data/listings.csv.gz
# !gunzip listings.csv.gz

# %%
ls
# Out:
# 1_hello_tensorflow.ipynb*    LICENSE*                hello_core
# 2_getting_started.ipynb*     Matplot examples.ipynb  listings.csv
# 3_mnist_from_scratch.ipynb*  StockPrediction.ipynb   listings.csv.gz
# Airbnb.ipynb                 Stocks.ipynb            stock_session.py
# BUILD*                       Tensorflow.ipynb

# %%
df = pd.read_csv('listings.csv')
# df.head()
df.loc[0:10, ['bedrooms', 'accommodates', 'beds', 'price']]
# df.describe()
# df.shape
# Out:
#     bedrooms  accommodates  beds    price
# 0        1.0             4   2.0  $160.00
# 1        3.0             6   3.0  $350.00
# 2        1.0             1   1.0   $50.00
# 3        1.0             2   1.0   $95.00
# 4        1.0             4   1.0   $50.00
# 5        2.0             4   4.0   $99.00
# 6        2.0             4   2.0  $100.00
# 7        1.0             2   1.0  $100.00
# 8        1.0             2   1.0   $38.00
# 9        1.0             2   1.0   $71.00
# 10       2.0             4   2.0   $97.00

# %%
list(df)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
# ...

# %%
#### df.loc[0:5, ['bedrooms', 'accommodates', 'price']]

our_accommodate_value = 3  # our space can accomodate 3 people. find similar properties
interesting_columns = ['bedrooms', 'accommodates', 'beds', 'price', 'distance']

# similar = df[df['accommodates'] == 3]
# similar.reset_index(inplace=True)
# similar.loc[0:10, ['bedrooms', 'accommodates', 'beds', 'price']]

# # calculate difference for all observations
df['distance'] = np.abs(df.accommodates - our_accommodate_value)
# df.distance.value_counts().sort_index()


# # # randomize the set of exact matches (to remove bias)
# why is sort returning distance of 1 and not 0?????
# df = df[df['distance'] == 0]
# df.reset_index(inplace=True)
# df.loc[0:10, ['bedrooms', 'accommodates', 'beds', 'price', 'distance']]


df = df.sample(frac=1, random_state=0)
df = df.sort_values('distance')
# df.loc[0:10, ['bedrooms', 'accommodates', 'beds', 'price', 'distance']]
df[interesting_columns].head(15)
# Out:
#       bedrooms  accommodates  beds      price  distance
# 2161       1.0             3   1.0    $105.00         0
# 71         1.0             3   1.0    $128.00         0
# 1644       1.0             3   1.0    $100.00         0
# 1539       1.0             3   1.0  $1,000.00         0
# 3042       0.0             3   2.0     $95.00         0
# 3226       0.0             3   1.0     $91.00         0
# 2986       1.0             3   1.0    $250.00         0
# 2489       1.0             3   1.0    $120.00         0
# 1209       1.0             3   1.0    $174.00         0
# 690        1.0             3   1.0    $125.00         0
# 3593       0.0             3   1.0     $85.00         0
# 3163       1.0             3   1.0    $126.00         0
# 423        1.0             3   2.0    $130.00         0
# 1792       1.0             3   1.0    $119.00         0
# 891        1.0             3   1.0    $104.00         0

# %%
# convert prices (with $) for float values
df['price'] = df.price.str.replace("\$|,", '').astype(float)
df[df['distance'] == 0].price.mean()
# mean_price = df[df['distance' == 0]].price.mean()
# mean_price
# Out:
# 146.16919739696311

# %%
df.drop('distance', axis=1)
train_df = df.copy().iloc[:2792]
test_df = df.copy().iloc[2792:]

def predict_price(new_listing_value,feature_column):
    temp_df = train_df
    temp_df['distance'] = np.abs(dc_listings[feature_column] - new_listing_value)
    temp_df = temp_df.sort_values('distance')
    knn_5 = temp_df.price.iloc[:5]
    predicted_price = knn_5.mean()
    return(predicted_price)
# Out:
#            id                           listing_url       scrape_id  \
# 2161  7725273  https://www.airbnb.com/rooms/7725273  20151002231825
# 71    6564932  https://www.airbnb.com/rooms/6564932  20151002231825
# 1644  5606999  https://www.airbnb.com/rooms/5606999  20151002231825
# 1539  8131716  https://www.airbnb.com/rooms/8131716  20151002231825
# 3042  7274483  https://www.airbnb.com/rooms/7274483  20151002231825
# 3226  6348926  https://www.airbnb.com/rooms/6348926  20151002231825
# 2986   782970   https://www.airbnb.com/rooms/782970  20151002231825
# 2489  1854624  https://www.airbnb.com/rooms/1854624  20151002231825
# 1209  4359559  https://www.airbnb.com/rooms/4359559  20151002231825
# 690   7761251  https://www.airbnb.com/rooms/7761251  20151002231825
# 3593  4325183  https://www.airbnb.com/rooms/4325183  20151002231825
# 3163  7074187  https://www.airbnb.com/rooms/7074187  20151002231825
# 423   5396268  https://www.airbnb.com/rooms/5396268  20151002231825
# ...
